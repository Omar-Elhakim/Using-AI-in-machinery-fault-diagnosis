# %%
import preloader as PreLoader;
import notebookcfa27bdb31 as ArrayGenerator;
# Out:
# Retrieving notices: ...working... done
# | WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.1.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.1.2
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gdown
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     filelock-3.13.1            |     pyhd8ed1ab_0          15 KB  conda-forge
#     gdown-5.1.0                |     pyhd8ed1ab_0          21 KB  conda-forge
#     openssl-3.2.1              |       hd590300_1         2.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   filelock           conda-forge/noarch::filelock-3.13.1-pyhd8ed1ab_0
#   gdown              conda-forge/noarch::gdown-5.1.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   openssl                                  3.2.1-hd590300_0 --> 3.2.1-hd590300_1
#
#
#
# Downloading and Extracting Packages
# filelock-3.13.1      | 15 KB     |                                       |   0%
# gdown-5.1.0          | 21 KB     |                                       |   0%
#
# openssl-3.2.1        | 2.7 MB    |                                       |   0%
#
# filelock-3.13.1      | 15 KB     | ##################################### | 100%
# filelock-3.13.1      | 15 KB     | ##################################### | 100%
# gdown-5.1.0          | 21 KB     | ##################################### | 100%
#
# openssl-3.2.1        | 2.7 MB    | ##################################### | 100%
#
#
#
#
#
# done
# done
# done
# /opt/conda/lib/python3.10/site-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=10o9CXx4oPyayrD9CJXv8TqLXanT-nLIZ
# From (redirected): https://drive.google.com/uc?id=10o9CXx4oPyayrD9CJXv8TqLXanT-nLIZ&confirm=t&uuid=ee9b8047-c131-4fdb-baa9-8e052ae60f6d
# To: /kaggle/working/dataset2.zip
# 100%|█████████████████████████████████████████| 182M/182M [00:00<00:00, 219MB/s]
# Archive:  dataset2.zip
#    creating: datasets/vhr/
#   inflating: datasets/vhr/0.csv
#   inflating: datasets/vhr/1.csv
#   inflating: datasets/vhr/10.csv
#   inflating: datasets/vhr/11.csv
#   inflating: datasets/vhr/2.csv
#   inflating: datasets/vhr/3.csv
#   inflating: datasets/vhr/4.csv
#   inflating: datasets/vhr/5.csv
#   inflating: datasets/vhr/6.csv
#   inflating: datasets/vhr/7.csv
#   inflating: datasets/vhr/8.csv
#   inflating: datasets/vhr/9.csv
#   inflating: datasets/vhr/metadata.csv
#    creating: datasets/vlr/
#   inflating: datasets/vlr/0.csv
#   inflating: datasets/vlr/1.csv
#   inflating: datasets/vlr/10.csv
#   inflating: datasets/vlr/11.csv
#   inflating: datasets/vlr/2.csv
#   inflating: datasets/vlr/3.csv
#   inflating: datasets/vlr/4.csv
#   inflating: datasets/vlr/5.csv
#   inflating: datasets/vlr/6.csv
#   inflating: datasets/vlr/7.csv
#   inflating: datasets/vlr/8.csv
#   inflating: datasets/vlr/9.csv
#   inflating: datasets/vlr/metadata.csv

# %%
preloader = PreLoader.PreLoader('vhr')

# %%
preloader.df.columns
# Out:
# Index(['name', 'date', 'status', 'rpm', 'bearing_abbs', 'standardized_faults',
#        'report_name', 'zone', 'area', 'factory', 'type', 'ts_shape_no_nans'],
#       dtype='object')

# %%
ts = preloader.get_3d_ts_array()
labels = preloader.get_labels_array("faults")

# %%
x,y=ArrayGenerator.generate_dataset_array(3,ts,labels,'channel')
# Out:
# {'Faults classified': 'Flow problem', 'Channels taken': 'Machine channels only', 'Labels array': 'Binary'}

# %%
x,y=ArrayGenerator.apply_sliding_window(x,y,2048,0.15,False)

# %%
# !pip install tsai;
# Out:
# Collecting tsai
#   Downloading tsai-0.3.9-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: fastai>=2.7.14 in /opt/conda/lib/python3.10/site-packages (from tsai) (2.7.14)
# Collecting pyts>=0.12.0 (from tsai)
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: imbalanced-learn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from tsai) (0.12.0)
# Requirement already satisfied: psutil>=5.4.8 in /opt/conda/lib/python3.10/site-packages (from tsai) (5.9.3)
# Requirement already satisfied: scikit-learn>=1.2 in /opt/conda/lib/python3.10/site-packages (from tsai) (1.2.2)
# Requirement already satisfied: torch<2.3,>=1.10 in /opt/conda/lib/python3.10/site-packages (from tsai) (2.1.2)
# Requirement already satisfied: pip in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (23.3.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (21.3)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (1.5.29)
# Requirement already satisfied: torchvision>=0.11 in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (0.16.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (3.7.5)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (2.1.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (2.31.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (6.0.1)
# Requirement already satisfied: fastprogress>=0.2.4 in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (9.5.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (1.11.4)
# Requirement already satisfied: spacy<4 in /opt/conda/lib/python3.10/site-packages (from fastai>=2.7.14->tsai) (3.7.2)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn>=0.11.0->tsai) (1.26.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn>=0.11.0->tsai) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from imbalanced-learn>=0.11.0->tsai) (3.2.0)
# Requirement already satisfied: numba>=0.55.2 in /opt/conda/lib/python3.10/site-packages (from pyts>=0.12.0->tsai) (0.58.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch<2.3,>=1.10->tsai) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch<2.3,>=1.10->tsai) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch<2.3,>=1.10->tsai) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch<2.3,>=1.10->tsai) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch<2.3,>=1.10->tsai) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch<2.3,>=1.10->tsai) (2024.2.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.55.2->pyts>=0.12.0->tsai) (0.41.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (4.66.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (2.5.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (69.0.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy<4->fastai>=2.7.14->tsai) (3.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->fastai>=2.7.14->tsai) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->fastai>=2.7.14->tsai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->fastai>=2.7.14->tsai) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->fastai>=2.7.14->tsai) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->fastai>=2.7.14->tsai) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch<2.3,>=1.10->tsai) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fastai>=2.7.14->tsai) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fastai>=2.7.14->tsai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fastai>=2.7.14->tsai) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fastai>=2.7.14->tsai) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->fastai>=2.7.14->tsai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->fastai>=2.7.14->tsai) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->fastai>=2.7.14->tsai) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch<2.3,>=1.10->tsai) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.7.14->tsai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<4->fastai>=2.7.14->tsai) (2.14.6)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->fastai>=2.7.14->tsai) (1.16.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai>=2.7.14->tsai) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<4->fastai>=2.7.14->tsai) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<4->fastai>=2.7.14->tsai) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<4->fastai>=2.7.14->tsai) (0.16.0)
# Downloading tsai-0.3.9-py3-none-any.whl (324 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.3/324.3 kB 1.9 MB/s eta 0:00:00
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 17.5 MB/s eta 0:00:00
# Installing collected packages: pyts, tsai
# Successfully installed pyts-0.13.0 tsai-0.3.9

# %%
from  tsai.all import *

# %%
splits = get_splits(
    y , valid_size=0.2, random_state=23, shuffle=True, balance=True
)
splits
# Out:
# ((#5684) [822,4497,6071,3371,3787,6499,5967,171,1789,4634...],
#  (#1327) [356,753,4180,3392,3949,5935,5151,1887,4072,5844...])

# %%
tfms = [None, [TSStandardize(by_var=True), Categorize()]]
batch_tfms = [TSStandardize(by_sample=True)]
dls = get_ts_dls(
    x ,
    y ,
    splits=splits,
    tfms=tfms,
    shuffle_train=True,
    batch_tfms=batch_tfms,
    bs=[64, 256],
)

# %%
del x
del y

# %%
dls.show_batch(sharex=True)

# %%
model = InceptionTime(dls.vars, dls.c)
learn = Learner(dls, model, metrics=[accuracy, Precision(), Recall(), F1Score()])

# %%
learn.fit_one_cycle(15, lr_max=learn.lr_find(), cbs=[PredictionDynamics()])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.599265</td>
#       <td>0.636558</td>
#       <td>0.646571</td>
#       <td>0.800499</td>
#       <td>0.452113</td>
#       <td>0.577858</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.567390</td>
#       <td>0.610025</td>
#       <td>0.684250</td>
#       <td>0.708155</td>
#       <td>0.697183</td>
#       <td>0.702626</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.549533</td>
#       <td>1.084179</td>
#       <td>0.589299</td>
#       <td>0.567678</td>
#       <td>0.974648</td>
#       <td>0.717470</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.522778</td>
#       <td>1.020249</td>
#       <td>0.621703</td>
#       <td>0.587690</td>
#       <td>0.981690</td>
#       <td>0.735232</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.505935</td>
#       <td>0.741158</td>
#       <td>0.705350</td>
#       <td>0.660624</td>
#       <td>0.923944</td>
#       <td>0.770405</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.496202</td>
#       <td>0.511273</td>
#       <td>0.746797</td>
#       <td>0.811667</td>
#       <td>0.685915</td>
#       <td>0.743511</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.478026</td>
#       <td>0.817570</td>
#       <td>0.551620</td>
#       <td>0.861635</td>
#       <td>0.192958</td>
#       <td>0.315305</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.455229</td>
#       <td>0.468336</td>
#       <td>0.787491</td>
#       <td>0.805714</td>
#       <td>0.794366</td>
#       <td>0.800000</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.432686</td>
#       <td>0.446735</td>
#       <td>0.795026</td>
#       <td>0.844340</td>
#       <td>0.756338</td>
#       <td>0.797920</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.403167</td>
#       <td>0.544629</td>
#       <td>0.708365</td>
#       <td>0.883610</td>
#       <td>0.523944</td>
#       <td>0.657825</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.376528</td>
#       <td>0.562893</td>
#       <td>0.694800</td>
#       <td>0.913279</td>
#       <td>0.474648</td>
#       <td>0.624652</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.342170</td>
#       <td>0.401546</td>
#       <td>0.826677</td>
#       <td>0.864742</td>
#       <td>0.801408</td>
#       <td>0.831871</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.314160</td>
#       <td>0.374734</td>
#       <td>0.832705</td>
#       <td>0.847578</td>
#       <td>0.838028</td>
#       <td>0.842776</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.288569</td>
#       <td>0.365386</td>
#       <td>0.834966</td>
#       <td>0.833107</td>
#       <td>0.864789</td>
#       <td>0.848652</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.277220</td>
#       <td>0.367167</td>
#       <td>0.836473</td>
#       <td>0.850640</td>
#       <td>0.842254</td>
#       <td>0.846426</td>
#       <td>00:20</td>
#     </tr>
#   </tbody>
# </table>
#     train_loss  valid_loss  accuracy  precision_score  recall_score  f1_score
# 14     0.27722    0.367167  0.836473          0.85064      0.842254  0.846426

# %%
learn.show_probas()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
valid_dl = dls.valid
valid_probas, valid_targets, valid_preds = learn.get_preds(
    dl=valid_dl, with_decoded=True
)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
positive_probs = valid_probas[:, 1]

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt


# Draw ROC curve to help us adjust the threshold to a better value.
fpr, tpr, thresholds = roc_curve(valid_targets, positive_probs)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color="blue", lw=2, label=f"ROC curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], color="gray", linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.show()

# %%
# We can calculate the optimum value for the threshold from the following code:
youden_index = tpr - fpr
optimal_threshold = thresholds[np.argmax(youden_index)]
print("Optimal threshold:", optimal_threshold)
# Out:
# Optimal threshold: 0.5250592

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

positive_probs = valid_probas[:, 1]

threshold = optimal_threshold  ###Adjust threshold if required. Use the optimal one found in the previous cell.

valid_preds_adjusted = (positive_probs > threshold).long()

accuracy = accuracy_score(valid_targets, valid_preds_adjusted)
precision = precision_score(valid_targets, valid_preds_adjusted)
recall = recall_score(valid_targets, valid_preds_adjusted)
f1 = f1_score(valid_targets, valid_preds_adjusted)

print("Adjusted Threshold Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Adjusted Threshold Metrics:
# Accuracy: 0.8395
# Precision: 0.8628
# Recall: 0.8324
# F1 Score: 0.8473

# %%
# Plot confusion matrix after adjsuting the threshold
from sklearn.metrics import confusion_matrix
import seaborn as sns


cm = confusion_matrix(valid_targets, valid_preds_adjusted)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel("Predicted Labels (Adjusted)")
plt.ylabel("True Labels")
plt.title("Confusion Matrix (Adjusted Threshold)")
plt.show()
